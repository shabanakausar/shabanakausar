# %% [markdown]
# <a href="https://colab.research.google.com/github/shabanakausar/shabanakausar/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
face_cascade =cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
#read the image
img = cv2.imread('fixed.png')

# %%
# detect faces
faces = face_cascade.detectMultiScale(img, 1.1,4)

# %%
# draw a rectangle around the faces
for (x, y, w, h) in faces:
     cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)

# %%
# display the output
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# cv2.imshow( img) because it creates error
cv2.waitKey(30)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900>
# -1
